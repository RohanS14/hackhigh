# %% [markdown]
# ## Integrating Gene Set Enrichment Analysis with CBioPortal DataHub
#
# Emma Chen, Kevin Yu, Chelsea Lai, Rohan Subramanian
#
# CBSP Hackathon 2024

# %%
from cbio_py import cbio_mod as cb

import sys
import os

# Get the absolute path to the parent directory
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Add it to sys.path if it's not already included
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %% [markdown]
# ## Run GSEA

# %%
from scripts.getGSEA import getGSEA

# %%
# Data file to use
dataFile = "../data/uvm_tgca.txt"

# Gene set to use
geneSetFile = "../scripts/input/defaultGeneSets.txt"

# Output file
resultFile =  "../results/gsea1_uvm_all.csv"

pre_res = getGSEA(geneSetFile, dataFile, sampleList=None, resultFile=None)
# Out:
# /Users/rohansubramanian/Desktop/MSK/hackathon/hackhigh/scripts/getGSEA.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleanfile['Average'] = cleanfile[column_names].mean(axis=1)
# 2024-06-17 14:35:53,525 [WARNING] Duplicated values found in preranked stats: 0.64% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.

# %% [markdown]
# ## Visualizing Enrichment Scores

# %%
def plotGSEA(term):
    axs = pre_res.plot(terms=term)
    new_title = term.split("__")[1]
    axs.suptitle(new_title)

# %%
plotGSEA('GO_Molecular_Function_2023__G Protein-Coupled Receptor Activity (GO:0004930)')

# %%
plotGSEA('GO_Molecular_Function_2023__Chemokine Receptor Activity (GO:0004950)')

# %%
plotGSEA('GO_Molecular_Function_2023__Death Receptor Binding (GO:0005123)')
